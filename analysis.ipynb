# %%
for line in open('food-world-cup-data.csv'):
    cleaned_line = line.strip()
    cleaned_list = cleaned_line.split(',')
    print(cleaned_list[25])
# Out:
# Please rate how much you like the traditional cuisine of Italy.
# 5
# 5
# 4
# 4
# 4
# 5
# 3
# 4
# 4
#
# 4
# 3
# 4
# 3
# 4
# 5
# 4
#
# 3
# N/A
# 5
# 5
#
# 4
# 4
# 5
#
# 4
# 2
# 4
# 5
# 3
# 4
# 3
# 3
# 4
# 2
# 5
# 4
# 3
# 5
# N/A
# 5
# 5
# 4
# 5
# 4
# N/A
# N/A
# 3
# 5
# 3
# 5
# 5
# N/A
# 5
# 4
# 2
# 4
# 4
# 5
#
# 4
# 3
# 4
# 4
# 4
# 5
# 4
# 5
# 2
# 5
# 5
#
# 3
# 4
# 5
# 5
# 1
# 4
# 5
# 5
# 4
#
# 5
# 3
# 5
# 3
# 2
# 5
# 4
# 3
# 4
# 4
# 2
# 3
# N/A
# 3
# 3
#
# 5
#
# 5
# 3
# 4
# 5
# 3
# N/A
# 4
# 4
# 4
# 1
# 4
# 4
# 4
# 4
# 4
# 4
# 3
# 4
# 3
# 5
# 3
# 4
# N/A
# 4
# 4
# 4
#
#
# 5
# 3
# 5
# 5
# 5
# 5
# 3
# 4
# 4
# 5
# 5
# 4
# 5
# 5
# 4
# 4
#
# 4
# 3
#
# 5
# 5
# 3
# 4
# 3
# 3
# 4
# 4
# 5
# 4
# 4
# 2
# 4
# 4
# 5
# 5
# 3
# 4
# 3
# 4
# 3
# 4
# 3
# 4
# 5
# 5
# 5
#
# 2
# 5
# 5
# 4
# 5
# N/A
# 4
# 5
#
#
# 5
#
# 5
# 3
# 3
# 4
# 3
# 3
# 3
# 3
# 4
# 4
# 4
# 3
# 4
# 3
# 2
# 3
# 3
# 5
# 3
# 4
# 4
# 5
# 3
# 5
#
# 5
#
# 2
# 4
#
# 5
# N/A
# 4
# 3
# 3
# 4
# 5
# 3
# 5
# 4
# 5
# 4
# 4
# 5
# 3
# 2
# 3
# 5
# ...

# %%
import pandas as pd
import numpy as np
foods = pd.read_csv('food-world-cup-data.csv')
foods.head()
# Out:
#    RespondentID  \
# 0    3308895255
# 1    3308891308
# 2    3308891135
# 3    3308879091
# 4    3308871671
#
#   Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?  \
# 0                                       Intermediate
# 1                                             Novice
# 2                                       Intermediate
# 3                                             Novice
# 4                                             Novice
#
#   How much, if at all, are you interested in cuisines from different parts of the world?  \
# 0                                               Some
# 1                                               Some
# 2                                              A lot
# 3                                          Not much�
# 4                                          Not much�
#
#    Please rate how much you like the traditional cuisine of Algeria:  \
# ...

# %%
import pandas as pd
import numpy as np
foods = pd.read_csv('food-world-cup-data.csv')
foods['Please rate how much you like the traditional cuisine of Brazil.']
# Out:
# 0       3.0
# 1       3.0
# 2       4.0
# 3       NaN
# 4       NaN
#        ...
# 1368    3.0
# 1369    NaN
# 1370    NaN
# 1371    4.0
# 1372    NaN
# Name: Please rate how much you like the traditional cuisine of Brazil., Length: 1373, dtype: float64

# %%
foods.iloc[27]
# Out:
# RespondentID                                                                                                                           3308784370
# Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?                        Intermediate
# How much, if at all, are you interested in cuisines from different parts of the world?                                                      A lot
# Please rate how much you like the traditional cuisine of Algeria:                                                                             3.0
# Please rate how much you like the traditional cuisine of Argentina.                                                                           3.0
# Please rate how much you like the traditional cuisine of�Australia.                                                                           3.0
# ...

# %%
print(foods.iloc[3,25])
# Out:
# 4.0

# %%
foods.iloc[:4,3]
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    NaN
# Name: Please rate how much you like the traditional cuisine of Algeria:, dtype: float64

# %%
foods.iloc[-25:,7]
# Out:
# 1348    NaN
# 1349    NaN
# 1350    NaN
# 1351    NaN
# 1352    NaN
# 1353    NaN
# 1354    NaN
# 1355    NaN
# 1356    3.0
# 1357    NaN
# 1358    NaN
# 1359    NaN
# 1360    NaN
# 1361    NaN
# 1362    NaN
# 1363    NaN
# 1364    NaN
# 1365    3.0
# 1366    NaN
# 1367    NaN
# 1368    NaN
# 1369    NaN
# 1370    NaN
# 1371    NaN
# 1372    NaN
# Name: Please rate how much you like the traditional cuisine of Bosnia and Herzegovina., dtype: float64

# %%
foods.iloc[[40,25], 5]
# Out:
# 40   NaN
# 25   NaN
# Name: Please rate how much you like the traditional cuisine of�Australia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Italy.'] == 3.0
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1368    False
# 1369    False
# 1370    False
# 1371    False
# 1372    False
# Name: Please rate how much you like the traditional cuisine of Italy., Length: 1373, dtype: bool

# %%
foods['Please rate how much you like the traditional cuisine of Italy.'] == 33
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1368    False
# 1369    False
# 1370    False
# 1371    False
# 1372    False
# Name: Please rate how much you like the traditional cuisine of Italy., Length: 1373, dtype: bool

# %%
foods.loc[foods['Please rate how much you like the traditional cuisine of Italy.'] == 33]
# Out:
# Empty DataFrame
# ...

# %%
foods.columns
# Out:
# Index(['RespondentID',
#        'Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?',
#        'How much, if at all, are you interested in cuisines from different parts of the world?',
#        'Please rate how much you like the traditional cuisine of Algeria:',
#        'Please rate how much you like the traditional cuisine of Argentina.',
#        'Please rate how much you like the traditional cuisine of�Australia.',
#        'Please rate how much you like the traditional cuisine of Belgium.',
#        'Please rate how much you like the traditional cuisine of Bosnia and Herzegovina.',
#        'Please rate how much you like the traditional cuisine of Brazil.',
#        'Please rate how much you like the traditional cuisine of Cameroon.',
#        'Please rate how much you like the traditional cuisine of Chile.',
#        'Please rate how much you like the traditional cuisine of Colombia.',
# ...

# %%
foods['Please rate how much you like the traditional cuisine of Ethiopia.'].describe()
# Out:
# count    396.000000
# mean       3.257576
# std        1.057496
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ethiopia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Italy.'].max()
# Out:
# 5.0

# %%
foods['Please rate how much you like the traditional cuisine of Italy.'].value_counts()
# Out:
# Please rate how much you like the traditional cuisine of Italy.
# 5.0    607
# 4.0    438
# 3.0    144
# 2.0      5
# 1.0      3
# Name: count, dtype: int64

# %%
foods['Please rate how much you like the traditional cuisine of Algeria:'].describe()
# Out:
# count    188.000000
# mean       3.058511
# std        0.926024
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Algeria:, dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Argentina.'].describe()
# Out:
# count    470.000000
# mean       3.523404
# std        0.754860
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Argentina., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Belgium.'].describe()
# Out:
# count    474.000000
# mean       3.529536
# std        0.744375
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Belgium., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Bosnia and Herzegovina.'].describe()
# Out:
# count    156.000000
# mean       2.891026
# std        0.869362
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Bosnia and Herzegovina., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Brazil.'].describe()
# Out:
# count    547.000000
# mean       3.606947
# std        0.782704
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Brazil., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Cameroon.'].describe()
# Out:
# count    124.000000
# mean       3.153226
# std        1.074799
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Cameroon., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Chile.'].describe()
# Out:
# count    420.000000
# mean       3.445238
# std        0.724182
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Chile., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Colombia.'].describe()
# Out:
# count    383.000000
# mean       3.342037
# std        0.792955
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Colombia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Costa Rica.'].describe()
# Out:
# count    418.000000
# mean       3.461722
# std        0.732735
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Costa Rica., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Croatia.'].describe()
# Out:
# count    206.000000
# mean       3.150485
# std        0.878843
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Croatia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Ecuador.'].describe()
# Out:
# count    291.000000
# mean       3.292096
# std        0.826651
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ecuador., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of England.'].describe()
# Out:
# count    1054.000000
# mean        3.031309
# std         0.843931
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of England., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of France.'].describe()
# Out:
# count    1046.000000
# mean        3.768642
# std         0.944392
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of France., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Germany.'].describe()
# Out:
# count    1034.000000
# mean        3.464217
# std         0.882867
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of Germany., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Ghana.'].describe()
# Out:
# count    152.000000
# mean       2.960526
# std        1.009108
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ghana., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Greece.'].describe()
# Out:
# count    1017.000000
# mean        3.801377
# std         0.861398
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of Greece., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Honduras.'].describe()
# Out:
# count    274.000000
# mean       3.208029
# std        0.819055
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Honduras., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Iran.'].describe()
# Out:
# count    308.000000
# mean       3.194805
# std        1.077323
# min        1.000000
# 25%        2.750000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Iran., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Italy.'].describe()
# Out:
# count    1197.000000
# mean        4.370927
# std         0.727683
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of Italy., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Ivory Coast.'].describe()
# Out:
# count    123.000000
# mean       3.065041
# std        0.972910
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ivory Coast., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Japan.'].describe()
# Out:
# count    1066.000000
# mean        3.695122
# std         0.970898
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of Japan., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Mexico.'].describe()
# Out:
# count    1222.000000
# mean        3.976268
# std         0.851992
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of Mexico., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of the Netherlands.'].describe()
# Out:
# count    391.000000
# mean       3.322251
# std        0.729236
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of the Netherlands., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Nigeria.'].describe()
# Out:
# count    164.000000
# mean       2.853659
# std        0.880908
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Nigeria., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Portugal.'].describe()
# Out:
# count    462.000000
# mean       3.523810
# std        0.746994
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Portugal., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Russia.'].describe()
# Out:
# count    553.000000
# mean       2.945750
# std        0.885033
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Russia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of South Korea.'].describe()
# Out:
# count    579.000000
# mean       3.198618
# std        0.970284
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of South Korea., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Spain.'].describe()
# Out:
# count    908.000000
# mean       3.770925
# std        0.791599
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Spain., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Switzerland.'].describe()
# Out:
# count    539.000000
# mean       3.389610
# std        0.749451
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Switzerland., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of United States.'].describe()
# Out:
# count    1253.000000
# mean        3.953711
# std         0.911988
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of United States., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Uruguay.'].describe()
# Out:
# count    179.000000
# mean       3.134078
# std        0.843954
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Uruguay., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of China.'].describe()
# Out:
# count    1158.000000
# mean        3.685665
# std         0.919200
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of China., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of India.'].describe()
# Out:
# count    1028.000000
# mean        3.416342
# std         1.171640
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Please rate how much you like the traditional cuisine of India., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Thailand.'].describe()
# Out:
# count    931.000000
# mean       3.778733
# std        0.985060
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Thailand., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Turkey.'].describe()
# Out:
# count    415.000000
# mean       3.436145
# std        0.900963
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Turkey., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Cuba.'].describe()
# Out:
# count    713.000000
# mean       3.542777
# std        0.788742
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Cuba., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Ethiopia.'].describe()
# Out:
# count    396.000000
# mean       3.257576
# std        1.057496
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ethiopia., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Vietnam.'].describe()
# Out:
# count    718.000000
# mean       3.434540
# std        1.024405
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Vietnam., dtype: float64

# %%
foods['Please rate how much you like the traditional cuisine of Ireland.'].describe()
# Out:
# count    903.000000
# mean       3.245847
# std        0.790339
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Ireland., dtype: float64

# %%
foods['How much, if at all, are you interested in cuisines from different parts of the world?'].value_counts()
# Out:
# How much, if at all, are you interested in cuisines from different parts of the world?
# Some           651
# A lot          438
# Not much�      200
# Not at all�     84
# Name: count, dtype: int64

# %%
foods['Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?'].describe()
# Out:
# count             1373
# unique               4
# top       Intermediate
# freq               609
# Name: Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?, dtype: object

# %%
foods['Gender'].value_counts()
# Out:
# Gender
# Female    660
# Male      579
# Name: count, dtype: int64

# %%
foods['Age'].value_counts()
# Out:
# Age
# 45-60    345
# > 60     325
# 30-44    307
# 18-29    262
# Name: count, dtype: int64

# %%
foods['Household Income'].value_counts()
# Out:
# Household Income
# $50,000 - $99,999      320
# $25,000 - $49,999      210
# $100,000 - $149,999    161
# $0 - $24,999           138
# $150,000+              125
# Name: count, dtype: int64

# %%
foods['Education'].value_counts()
# Out:
# Education
# Bachelor degree                     386
# Some college or Associate degree    382
# Graduate degree                     325
# High school degree                  115
# Less than high school degree         20
# Name: count, dtype: int64

# %%
foods['Location (Census Region)'].value_counts()
# Out:
# Location (Census Region)
# Pacific               215
# South Atlantic        200
# East North Central    188
# Middle Atlantic       170
# West South Central    134
# West North Central    107
# Mountain              102
# New England            73
# East South Central     40
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Example — replace these with your actual means
countries = ["Algeria", "Argentina", "Australia", "Beligum", "Bosnia and Herzegovina", "Brazil", "Cameroon", "Chile", "Colombia", "Costa Rica", "Croatia", "Ecuador", "England", "France", "Germany", "Ghana", "Greece", "Honduras", "Iran", "Italy", "Ivory Coast", "Japan", "Mexico", "The Netherlands", "Nigeria", "Portugal", "Russia", "South Korea", "Spain", "Switzerland", "United States", "Uruguay", "China", "India", "Thailand", "Turkey", "Cuba", "Ethiopia", "Vietnam", "Ireland"]
mean_ratings = [3.06, 3.52, 3.33, 3.53, 2.89, 3.61, 3.15, 3.45, 3.34, 3.46, 3.15, 3.29, 3.03, 3.77, 3.46, 2.96, 3.80, 3.21, 3.19, 4.37, 3.07, 3.69, 3.98, 3.32, 2.85, 3.52, 2.95, 3.20, 3.77, 3.39, 3.95, 3.13, 3.69, 3.42, 3.78, 3.44, 3.54, 3.26, 3.43, 3.25]

plt.figure(figsize=(20, 6))
plt.bar(countries, mean_ratings)

plt.xlabel("Country")
plt.ylabel("Mean Rating")
plt.title("Appx. Cuisine Rating by Country")
plt.xticks(rotation=45)

plt.show()

# %%
foods['Please rate how much you like the traditional cuisine of�Australia.'].describe()
# Out:
# count    483.000000
# mean       3.327122
# std        0.781416
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of�Australia., dtype: float64

# %%
import matplotlib.pyplot as plt

labels = ["45-60", "> 60", "30-44", "18-29"]
sizes = [345, 325, 307, 262]  # percentages or counts

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Age Ranges for Respondents")
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ["Intermediate", "Novice", "Advanced", "Experts"]
sizes = [609, 547, 190, 27]  # percentages or counts

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Respondents' Level of Cuisine Knowledge")
plt.show()

# %%
# seeing how only experts would rate the most popular cuisine from this survey; lower than total mean
experts = foods.loc[foods["Generally speaking, how would you rate your level of knowledge�of cuisines from different parts of the world?"] == "Expert"]
experts["Please rate how much you like the traditional cuisine of Italy."].describe()
# Out:
# count    25.000000
# mean      4.280000
# std       1.061446
# min       1.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       5.000000
# Name: Please rate how much you like the traditional cuisine of Italy., dtype: float64

# %%
# testing how only experts would rate the least popular cuisine from this survey; lower than total mean
experts["Please rate how much you like the traditional cuisine of Nigeria."].describe()
# Out:
# count    14.000000
# mean      2.785714
# std       0.801784
# min       2.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max       4.000000
# Name: Please rate how much you like the traditional cuisine of Nigeria., dtype: float64

# %%
oldest_age = foods.loc[foods["Age"] == "45-60"]
oldest_age["Please rate how much you like the traditional cuisine of Italy."].describe()
# Out:
# count    328.000000
# mean       4.298780
# std        0.771669
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Italy., dtype: float64

# %%
oldest_age["Please rate how much you like the traditional cuisine of Nigeria."].describe()
# Out:
# count    43.000000
# mean      2.906977
# std       0.894799
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max       5.000000
# Name: Please rate how much you like the traditional cuisine of Nigeria., dtype: float64

# %%
youngest_age = foods.loc[foods["Age"] == "18-29"]
youngest_age["Please rate how much you like the traditional cuisine of Italy."].describe()
# Out:
# count    245.000000
# mean       4.440816
# std        0.702431
# min        2.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# Name: Please rate how much you like the traditional cuisine of Italy., dtype: float64

# %%
youngest_age["Please rate how much you like the traditional cuisine of Nigeria."].describe()
# Out:
# count    32.000000
# mean      2.843750
# std       0.919655
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max       5.000000
# Name: Please rate how much you like the traditional cuisine of Nigeria., dtype: float64
